# %%
import sys
import os
import numpy as np
import pandas as pd

sys.path.append('../')


from src_experiment import VisualisationOfLatenRepresentation

# %%
model_name = "small"
dataset = "new"
noise = 0.05
run_number = 20

obj = VisualisationOfLatenRepresentation(model_name, dataset, noise, run_number)
for epoch in obj.epochs[::6]:
    obj.show_epoch(epoch)
