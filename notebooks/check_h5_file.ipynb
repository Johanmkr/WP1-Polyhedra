# %%
import sys
import numpy as np
import matplotlib.pyplot as plt


sys.path.append('../')
from geobin_py.reconstruction import Tree, Region
from src_experiment.paths import outputs

# %%
h5file = outputs/ "moons_big/moons_big.h5"
epoch = 40
tree = Tree(h5file, epoch)
# Out:
#   - Loading Epoch 40...

# %%
all_nodes = np.concatenate([tree.get_regions_at_layer(l) for l in range(tree.L + 1)])

for node in all_nodes:
    print(f"Region {node.id} at layer {node.layer} has volume {node.volume}")
# Out:
# Node 0 at layer 0 has volume inf
# Node 1 at layer 1 has volume 0.0038263669913418666
# Node 2 at layer 1 has volume 0.025357121172405715
# Node 3 at layer 1 has volume 0.0028215515142532266
# Node 4 at layer 1 has volume 0.00984852932941733
# Node 5 at layer 1 has volume 0.002175177653364746
# Node 6 at layer 1 has volume 0.001989050351238681
# Node 7 at layer 1 has volume 0.00016389152300589797
# Node 8 at layer 1 has volume 0.0016124900750284436
# Node 9 at layer 1 has volume 0.0015741876185285672
# Node 10 at layer 1 has volume 0.0037001506986852808
# Node 11 at layer 1 has volume 0.008300879533948067
# Node 12 at layer 1 has volume 0.02276297137705991
# Node 13 at layer 1 has volume inf
# Node 14 at layer 1 has volume 0.007799241304262842
# Node 15 at layer 1 has volume 0.0016538218299363514
# Node 16 at layer 1 has volume 0.43745962512481945
# Node 17 at layer 1 has volume 6.638621613182096e-05
# Node 18 at layer 1 has volume 0.002454383107709709
# ...
