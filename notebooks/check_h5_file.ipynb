# %%
import sys
import numpy as np
import matplotlib.pyplot as plt


sys.path.append('../')
from visualization import plot_regions as pr
from geobin_py.reconstruction import Tree, Region
from src_experiment.paths import outputs
from src_experiment.estimate_quantities import ExperimentEvaluator

# %%
h5file = outputs/ "blobs_2d/blobs_2d.h5"
# epoch = 40
tree = Tree(h5file, 50)
# Out:
#   - Loading Epoch 50...

# %%
# Find total volume of

# %%
def histogram_for_layers(ax, tree, epoch):
    # 1. Determine the global min and max volumes to keep bins consistent across layers
    # (Optional, but recommended for visual comparison)
    all_volumes = []
    
    for layer in range(1, tree.L + 1):
        nodes = tree.get_regions_at_layer(layer)
        v_layer = [v.volume_es for v in nodes if v.volume_es > 0 and np.isfinite(v.volume_es)]
        all_volumes.extend(v_layer)

    if not all_volumes:
        return

    # 2. Create logarithmic bin edges
    # We take the log10 of the min and max to define the range
    min_v, max_v = min(all_volumes), max(all_volumes)
    bins = np.logspace(np.log10(min_v), np.log10(max_v), 50)

    # 3. Plot using the custom bins
    for layer in range(1, tree.L + 1):
        nodes = tree.get_regions_at_layer(layer)
        volumes = [node.volume_es for node in nodes if node.volume_es > 0 and np.isfinite(node.volume_es)]
        
        ax.hist(volumes, bins=bins, alpha=0.75, label=f"Layer {layer}")
    
    ax.set_xscale("log")
    ax.set_title(f"Volume distribution for epoch {epoch}")
    ax.set_xlabel("Volume (log scale)")
    ax.set_ylabel("Frequency")
    ax.legend()

# %%
import tqdm
fig, ax = plt.subplots(ncols=3, nrows=2, figsize=(15, 12))
for epoch, ax in tqdm.tqdm(zip([0,4,10,30,50], ax.flat)):
    tree = Tree(h5file, epoch)
    histogram_for_layers(ax, tree, epoch)
plt.show()
# Out:
# 0it [00:00, ?it/s]
#   - Loading Epoch 0...
# 1it [00:00,  1.66it/s]
#   - Loading Epoch 4...
# 2it [00:00,  2.31it/s]
#   - Loading Epoch 10...
# 3it [00:01,  2.52it/s]
#   - Loading Epoch 30...
# 4it [00:01,  2.58it/s]
#   - Loading Epoch 50...
# 5it [00:02,  2.44it/s]

# %%
pr.plot_grid(h5file, min_bound=0, max_bound=1, plot_points=True)
# Out:
# Scanning blobs_2d.h5...
#   - Loading Epoch 0...
#   - Loading Epoch 2...
#   - Loading Epoch 4...
#   - Loading Epoch 8...
#   - Loading Epoch 20...
#   - Loading Epoch 50...
#   > Rendering Epoch 0...
#   > Rendering Epoch 2...
#   > Rendering Epoch 4...
#   > Rendering Epoch 8...
#   > Rendering Epoch 20...
#   > Rendering Epoch 50...
# ✅ Visualization saved to: /home/johan/Documents/phd/WP1/geometric_binning_estimator/outputs/blobs_2d/blobs_2d_regions_grid.png

# %%
ev = ExperimentEvaluator(h5file)
# Out:
# Evaluating blobs_2d.h5...
#   - Loading Epoch 0...
#   - Loading Epoch 1...
#   - Loading Epoch 2...
#   - Loading Epoch 3...
#   - Loading Epoch 4...
#   - Loading Epoch 6...
#   - Loading Epoch 8...
#   - Loading Epoch 10...
#   - Loading Epoch 20...
#   - Loading Epoch 30...
#   - Loading Epoch 40...
#   - Loading Epoch 50...

# %%
ev.estimates
# Out:
# {'Mutual Information':     epoch        l1        l2        l3        l4
#  0       0  1.256385  1.953863  2.057812  2.097830
#  1       1  1.488937  1.929973  2.084478  2.102182
#  2       2  1.602734  2.012194  2.064853  2.077219
#  3       3  1.724449  2.035277  2.103464  2.109271
#  4       4  1.690987  2.023004  2.099938  2.109112
#  5       6  1.624635  2.051895  2.112461  2.115901
#  6       8  1.591556  2.080855  2.105597  2.107561
#  7      10  1.500314  2.040976  2.070651  2.077480
#  8      20  1.561220  2.055864  2.101611  2.107825
#  9      30  1.521635  2.065226  2.088415  2.105175
#  10     40  1.472596  2.028992  2.078472  2.116068
#  11     50  1.524352  2.063572  2.110175  2.126877}

# %%
MI = ev.estimates["Mutual Information"]

# %%
MI
# Out:
#     epoch        l1        l2        l3        l4
# 0       0  1.256385  1.953863  2.057812  2.097830
# 1       1  1.488937  1.929973  2.084478  2.102182
# 2       2  1.602734  2.012194  2.064853  2.077219
# 3       3  1.724449  2.035277  2.103464  2.109271
# 4       4  1.690987  2.023004  2.099938  2.109112
# 5       6  1.624635  2.051895  2.112461  2.115901
# 6       8  1.591556  2.080855  2.105597  2.107561
# 7      10  1.500314  2.040976  2.070651  2.077480
# 8      20  1.561220  2.055864  2.101611  2.107825
# 9      30  1.521635  2.065226  2.088415  2.105175
# 10     40  1.472596  2.028992  2.078472  2.116068
# 11     50  1.524352  2.063572  2.110175  2.126877

# %%
epochs = MI["epoch"]

# %%
fig, ax = plt.subplots()
for layer in ["l1", "l2", "l3", "l4"]:
    if layer in MI:
        ax.plot(epochs, MI[layer], marker='o', label=layer)
ax.set_xlabel("Epoch")
ax.set_ylabel("Mutual Information (bits)")
ax.set_title("Mutual Information Estimate vs Epoch")
ax.legend()
ax.grid()

# %%
volestev= ExperimentEvaluator(h5file, volume_key="volumes_es")
# Out:
# Evaluating blobs_2d.h5...
#   - Loading Epoch 0...
#   - Loading Epoch 1...
#   - Loading Epoch 2...
#   - Loading Epoch 3...
#   - Loading Epoch 4...
#   - Loading Epoch 6...
#   - Loading Epoch 8...
#   - Loading Epoch 10...
#   - Loading Epoch 20...
#   - Loading Epoch 30...
#   - Loading Epoch 40...
#   - Loading Epoch 50...

# %%
MI = volestev.estimates["Mutual Information"]

# %%
fig, ax = plt.subplots()
for layer in ["l1", "l2", "l3", "l4"]:
    if layer in MI:
        ax.plot(epochs, MI[layer], marker='o', label=layer)
ax.set_xlabel("Epoch")
ax.set_ylabel("Mutual Information Estimate")
ax.set_title("Mutual Information Estimate vs Epoch (using volume_es)")
ax.legend()
ax.grid()
