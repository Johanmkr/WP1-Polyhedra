# %%
import sys
import numpy as np
import matplotlib.pyplot as plt


sys.path.append('../')
from geobin_py.reconstruction import Tree, Region
from src_experiment.paths import outputs

# %%
# h5file = outputs/ "moons_big/moons_big.h5"
# epoch = 40
# tree = Tree(h5file, epoch)

# %%
# all_nodes = np.concatenate([tree.get_regions_at_layer(l) for l in range(tree.L + 1)])

# for node in all_nodes:
#     print(f"Region {node.id} at layer {node.layer} has volume {node.volume}")

# %%
def histogram_for_layers(ax, tree, epoch):
    # 1. Determine the global min and max volumes to keep bins consistent across layers
    # (Optional, but recommended for visual comparison)
    all_volumes = []
    
    for layer in range(1, tree.L + 1):
        nodes = tree.get_regions_at_layer(layer)
        v_layer = [v.volume for v in nodes if v.volume > 0 and np.isfinite(v.volume)]
        all_volumes.extend(v_layer)

    if not all_volumes:
        return

    # 2. Create logarithmic bin edges
    # We take the log10 of the min and max to define the range
    min_v, max_v = min(all_volumes), max(all_volumes)
    bins = np.logspace(np.log10(min_v), np.log10(max_v), 200)

    # 3. Plot using the custom bins
    for layer in range(1, tree.L + 1):
        nodes = tree.get_regions_at_layer(layer)
        volumes = [node.volume for node in nodes if node.volume > 0 and np.isfinite(node.volume)]
        
        ax.hist(volumes, bins=bins, alpha=0.75, label=f"Layer {layer}")
    
    ax.set_xscale("log")
    ax.set_title(f"Volume distribution for epoch {epoch}")
    ax.set_xlabel("Volume (log scale)")
    ax.set_ylabel("Frequency")
    ax.legend()

# %%
import tqdm
fig, ax = plt.subplots(ncols=3, nrows=2, figsize=(15, 12))
for epoch, ax in tqdm.tqdm(zip([0,4,10,20,30,40], ax.flat)):
    tree = Tree(h5file, epoch)
    histogram_for_layers(ax, tree, epoch)
plt.show()
# Out:
# 0it [00:00, ?it/s]
#   - Loading Epoch 0...
# 1it [00:09,  9.47s/it]
#   - Loading Epoch 4...
# 2it [00:17,  8.58s/it]
#   - Loading Epoch 10...
# 3it [00:30, 10.80s/it]
#   - Loading Epoch 20...
# 4it [00:49, 13.77s/it]
#   - Loading Epoch 30...
# 5it [01:00, 12.80s/it]
#   - Loading Epoch 40...
# 6it [01:11, 11.95s/it]
