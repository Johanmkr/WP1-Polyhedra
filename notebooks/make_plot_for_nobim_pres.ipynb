# %%
import numpy as np 
from sklearn.datasets import make_moons

# X_train, y_train = make_moons(n_samples=10000, noise=0.05, random_state=1)
# X_test, y_test = make_moons(n_samples=2500, noise=0.05, random_state=11)



# X_train_noise, y_train_noise = make_moons(n_samples=10000, noise=2, random_state=1)
# X_test_noise, y_test_noise = make_moons(n_samples=2500, noise=2, random_state=11)


(X_train, y_train), (X_test, y_test) = (make_moons(n_samples=10000, noise=0.05, random_state=1), make_moons(n_samples=2500, noise=0.05, random_state=11))

(X_train_noise, y_train_noise), (X_test_noise, y_test_noise) = (make_moons(n_samples=10000, noise=0.25, random_state=1), make_moons(n_samples=2500, noise=0.25, random_state=11))

# %%
# Plot the datasets

import matplotlib.pyplot as plt
fig, axs = plt.subplots(1,2, figsize=(10, 5), sharey=True)
axs[0].scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='viridis', s=5)
axs[0].set_title('Clean Moons Dataset')
axs[1].scatter(X_train_noise[:, 0], X_train_noise[:, 1], c=y_train_noise, cmap='viridis', s=5)
axs[1].set_title('Noisy Moons Dataset')
axs[1].set_xlabel(r"$X_1$")
axs[0].set_xlabel(r"$X_1$")
axs[0].set_ylabel(r"$X_2$")
fig.tight_layout()
plt.show()
